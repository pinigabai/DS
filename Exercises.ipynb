# %%
import math
num = int(input('Enter a number:'))
factors = []
factors_powers = {}
while num%2 == 0:
    factors.append(2)
    num = num//2
for i in range(3,int(math.sqrt(num))+1,2):
    while num%i == 0:
        factors.append(i)
        num = num//i
if num > 2:
    factors.append(num)
for i in factors:
    if i in factors_powers:
        factors_powers[i] += 1
    else:
        factors_powers[i] = 1
print(factors_powers)

num = int(input('Enter a number:'))
divisors = []
for i in range(1,num+1):
    if num%i == 0:
        divisors.append(i)
print(divisors)

num = int(input('Enter a number:'))
divisors = []
if num in (0,1):
    print('Not a prime number')
else:
    for i in range(2,num):
        if num%i == 0:
            print('Not a prime number')
            break
    else:
        print('A prime number')

num = int(input('Enter a number:'))
print(2, end=' ')
for i in range(3,num,2):
    for j in range(2,i):
        if i%j == 0:
            break
    else:
        print(i, end=' ')

num = int(input('Enter a number:'))
summ = 0
for i in range(1,num+1,2):
    summ += i
    if num == summ:
        print('A perfect square')
        break
else:
    print('Not a perfect square')

num1 = int(input('Enter the first number:'))
num2 = int(input('Enter the second number:'))
divisors = {}
for num in (num1,num2):
    divisors[num] = []
    for i in range(1,num+1):
        if num%i == 0:
            divisors[num].append(i)
common_divisors = set(divisors[next(iter(divisors))])
for key in divisors:
    common_divisors.intersection_update(divisors[key])
print('GCD:',max(common_divisors))

num1 = int(input('Enter the first number:'))
num2 = int(input('Enter the second number:'))
min_num = min(num1,num2)
max_num = max(num1,num2)
i = 1
while True:
    if (max_num*i)%min_num == 0:
        print('LCM:',max_num*i)
        break
    else:
        i += 1

num = int(input('Enter a number:'))
if num == 0:
    print('Factorial of',num,'is',1)
else:
    tmp = num
    factorial = tmp
    tmp -= 1
    while tmp > 0:
        factorial *= tmp
        tmp -= 1
print('Factorial of',num,'is',factorial)

num = int(input('Enter a number:'))
tmp = num
while tmp%2 == 0:
    tmp = tmp//2
if tmp == 1:
    print(num,'is a power of 2')
else:
    print(num,'is not a power of 2')

num = int(input('Enter a number:'))
summ = 0
while num > 0:
    digit = num%10
    summ += digit
    num = num//10
print('Summary of digits is',summ)

num = int(input('Enter a number:'))
tmp = num
reverse = 0
while tmp > 0:
    digit = tmp%10
    reverse = reverse*10+digit
    tmp = tmp//10
if num == reverse:
    print('A palindrome number')
else:
    print('Not a palindrome number')

n_fibo1 = [1,0]
for i in range(11):
    n_fibo1.append(n_fibo1[i]-n_fibo1[i+1])
print(n_fibo1)

n_fibo2 = [0,1]
for i in range(11):
    n_fibo2.insert(0,n_fibo2[1]-n_fibo2[0])
print(n_fibo2)

# %%
import os
if not os.path.exists('os_exercise'):
    os.mkdir('os_exercise')
    file1 = open('os_exercise\\file1.txt', 'w')
    file1.write('Hello from file1\n')
    file2 = open('os_exercise\\file2.txt', 'w')
    file2.write('Hello from file2\n')
    file3 = open('os_exercise\\file3.txt', 'w')
    file3.write('Hello from file3\n')
file1.close()
file2.close()
file3.close()
for file in os.listdir('os_exercise'):
    print(file)
os.rename('os_exercise\\file2.txt','os_exercise\\renamed_file2.txt')
os.remove('os_exercise\\file3.txt')
for file in os.listdir('os_exercise'):
    os.remove(os.path.join('os_exercise',file))
os.rmdir('os_exercise')

# %%
try:
    dividend = int(input('Enter the dividend:'))
    divisor = int(input('Enter the divisor:'))
    print('Result:',dividend/divisor)
except ZeroDivisionError:
    print('Divided by zero')
except ValueError:
    print('A non-numeric value was entered')
finally:
    print('Execution completed')

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def greet(self):
        print(f'Hello {self.name}! Your age is {self.age}.')
person = Person('Pini',38)
person.greet()

class Rectangle:
    def __init__(self,length = 1.0,width = 1.0):
        self.length = length
        self.width = width
    def area(self):
        print(f'Area: {self.length*self.width}')
    def perimeter(self):
        print(f'Perimeter: {2*self.length+2*self.width}')
rectangle = Rectangle()
rectangle.area()
rectangle.perimeter()

class BankAccount:
    def __init__(self,balance):
        self.__balance = balance
    def deposit(self,amount):
        self.__balance += amount
    def withdraw(self,amount):
        self.__balance -= amount
    def get_balance(self):
        return self.__balance
account = BankAccount(100)
account.deposit(100)
account.withdraw(50)
account.get_balance()

class Vehicle:
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model
    def describe(self):
        print(f'{self.brand} | {self.model}')
class Car(Vehicle):
    def __init__(self,brand,model,doors):
        super().__init__(brand,model)
        self.doors = doors
    def describe(self):
        print(f'{self.brand} | {self.model} | {self.doors} doors')
vehicle = Vehicle('Hyundai','i20')
vehicle.describe()
car = Car('Hyundai','i20',4)
car.describe()

class MathOperations:
    @staticmethod
    def add(a,b):
        return a+b
    @classmethod
    def is_even(cls,num):
        if num%2 == 0:
            return True
        return False
print(MathOperations.add(2,4))
print(MathOperations.is_even(4))

class Dog:
    def speak(self):
        print('woof')
class Cat:
    def speak(self):
        print('meow')
class Bird:
    def speak(self):
        print('chirp')
def animal_sound(animal):
    animal.speak()
dog = Dog()
animal_sound(dog)
cat = Cat()
animal_sound(cat)
bird = Bird()
animal_sound(bird)

class Temperature:
    def __init__(self,celsius):
        self.__celsius = celsius
    @property
    def celsius(self):
        return self.__celsius
    @celsius.setter
    def celsius(self,value):
        self.__celsius = value
    @property
    def fahrenheit(self):
        return self.__celsius*9/5+32
    @fahrenheit.setter
    def fahrenheit(self,value):
        self.__celsius = (value-32)*5/9
temp = Temperature(25)
print(f'Celsius: {temp.celsius}°C')
print(f'Fahrenheit: {temp.fahrenheit}°F')
temp.fahrenheit = 77
print(f'Celsius after setting Fahrenheit to 77°F: {temp.celsius}°C')

from abc import ABC, abstractmethod
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
class Circle(Shape):
    pi = 3.14
    def __init__(self,radius):
        self.radius = radius
    def area(self):
        print(f'Circle area: {Circle.pi*self.radius**2}')
class Square(Shape):
    def __init__(self,side):
        self.side = side
    def area(self):
        print(f'Square area: {self.side*self.side}')
circle = Circle(2)
circle.area()
square = Square(2)
square.area()

class Vector:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def __add__(self,other):
        return Vector(self.x+other.x,self.y+other.y)
    def __sub__(self,other):
        return Vector(self.x-other.x,self.y-other.y)
    def __str__(self):
        return f'Vector({self.x},{self.y})'
v1 = Vector(2,3)
v2 = Vector(4,1)
v3 = v1+v2
print(f'Addition: {v3}')
v4 = v1-v2
print(f'Subtraction: {v4}')

class Book:
    def __init__(self,title,author,year):
        self.title = title
        self.author = author
        self.year = year
class Library:
    books = []
    @classmethod
    def add_book(cls,book):
        cls.books.append({'title':book.title,
                          'author':book.author,
                          'year':book.year})
    @classmethod
    def list_books(cls):
        for book in cls.books:
            print(f'Title: {book['title']}, Author: {book['author']}, Year: {book['year']}')
book1 = Book('The Odyssey','Homer',1996)
book2 = Book('Harry Potter and the Goblet of Fire','J.K. Rowling',2000)
book3 = Book('The Road','Cormac McCarthy',2006)
Library.add_book(book1)
Library.add_book(book2)
Library.add_book(book3)
Library.list_books()

# %%
num = int(input('Enter the number of people:'))
prob = 1
days = 364
for _ in range(num-1):
    prob *= days/365
    days -= 1
print(f'The probability that at least two people share the same birthday is {(1-prob)*100:.2f}%')

# %%
import numpy as np
import matplotlib.pyplot as plt
#X = [10,20,30,40,50] [5,6,7,8,9] [1,2,3,4,5,6,7] [2,4,6,8,10] [40,35,50,30,60]
#Y = [80,70,60,50,40] [12,8,15,10,14] [50,55,60,65,70,75,80] [8,16,24,32,40] [600,550,750,450,900]
X = np.array([1,2,3,4,5])
Y = np.array([2,4,6,8,10])
print('Pearson correlation:',np.corrcoef(X,Y)[0,1])
plt.scatter(X,Y)
plt.show()
